# %%
import os
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np

demographics = pd.read_excel(r'/Users/taruna/Desktop/publication/Data/CP/demographics_cp_reduced.xlsx')
directory = '/Users/taruna/Desktop/publication/Data/CP'
directory2 = '/Users/taruna/Desktop/publication/Data'
df_list = []
list=[]
df_append =  pd.DataFrame()
final = pd.DataFrame()
colNames = ['LH.POS.x','LH.POS.y', 'LH.POS.z','LH.ROT.x', 'LH.ROT.y', 'LH.ROT.z', 'TH.POS.x', 'TH.POS.y','TH.POS.z','TH.ROT.x','TH.ROT.y','TH.ROT.z']
for dirpath, dirnames, filenames in os.walk(directory):
    path = os.path.basename(os.path.normpath(dirpath))
    appended_data =[]
   #  demographicsTrans = demographics.transpose()
    for name in demographics['Name']:

         if path in name:
            for filename in filenames:
               outfile = path+'.csv'
               if filename.endswith('imp_processed.csv'):
                  # print(filename)
                  with open(os.path.join(dirpath, filename)) as f:
                     
                    
                     df = pd.read_csv(f, skiprows=0, names=colNames, encoding="ISO-8859-1", delimiter=",")
                     dfTranspose = df.transpose()
                  
                     dt = demographics.loc[demographics['Name'] == path]
                     
                     
                     dtTranspose = dt.T
                     dtTranspose.columns = dtTranspose.iloc[0]
                     dtTranspose.reset_index(inplace=True)

                     # dtTranspose = dtTranspose[[0, 'Name', path]]
                     appended_data.append(df)
                    
                     
# see pd.concat documentation for more info
    if len(appended_data) >= 1:
      appended_data = pd.concat(appended_data, ignore_index=True)
      # add this line to merge gender data
      # df_list = pd.concat([appended_data, dtTranspose])
      print('after merge')
      print(df_list)
      combined = os.path.join(directory2, outfile)
      appended_data.to_csv(combined, index=False, encoding='utf-8-sig')     
                        
                     
print("main length")
print(len(df_list))
# Out:
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# after merge
# []
# main length
# 0
